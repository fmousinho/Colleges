# %%
import pandas as pd
from bs4 import BeautifulSoup

# %% [markdown]
# Process WSJ Info

# %%
def html_to_df(dir_path, name_convention, college_name_class):
    all_colleges = []
    file_index = 1
    
    while True:
        # Construct file path
        file_name = f"{name_convention}{file_index}.xml"
        full_path = f"{dir_path}/{file_name}"
        
        try:
            # Read and parse XML file
            with open(full_path, 'r') as file:
                file_content = file.read()
            
            # Parse with BeautifulSoup
            soup = BeautifulSoup(file_content, 'html.parser')
            
            # Get college names using existing pattern
            colleges = soup.find_all("p", class_=college_name_class)
            college_list = [name.text.strip() for name in colleges]
            
            # Add to master list
            all_colleges.extend(college_list)
            
            file_index += 1
            
        except FileNotFoundError:
            break
    
    # Create final dataframe
    df = pd.DataFrame(all_colleges, columns=['College Name'])
    return df

# %%
dir_path = "Data/WSJ2025"
name_convention = "WSJpage"
college_name_class = "css-95l4o0"


df = html_to_df(dir_path, name_convention, college_name_class)
df['WSJ Rank'] = df.index + 1

# %% [markdown]
# Sets up Gemini

# %%
import os
from dotenv import load_dotenv
import google.generativeai as genai
from google.ai.generativelanguage_v1beta.types import content
import json
import time

# Load environment variables from .env file
load_dotenv()

# Get the API key
GEMINI_API_KEY = os.getenv('GEMINI_API_KEY')

if GEMINI_API_KEY is None:
    raise ValueError("GEMINI_API_KEY not found in .env file")

genai.configure(api_key=GEMINI_API_KEY)

# %% [markdown]
# Program to retrieve acceptance rate and save to pickle

# %%
# Create the model
acceptance_rate_generation_config = {
  "temperature": 0,
  "top_p": 0.95,
  "top_k": 40,
  "max_output_tokens": 8192,
  "response_schema": content.Schema(
    type = content.Type.OBJECT,
    properties = {
      "acceptance rate": content.Schema(
        type = content.Type.STRING,
      ),
      "confidence": content.Schema(
        type = content.Type.STRING,
      ),
    },
  ),
  "response_mime_type": "application/json",
}

acceptance_rate_model = genai.GenerativeModel(
  model_name="gemini-2.0-flash-exp",
  generation_config=gacceptance_rate_generation_config,
  system_instruction="Seartch the web for the acceptance rate in 2024 for the provided university undergraduate name. Provide the response as a JSON.",
)

acceptance_rate_chat_session = acceptance_rate_model.start_chat()

# %%
def get_acceptance_rate(college_name):
    # Send message to chat session and get response
    response = acceptance_rate_chat_session.send_message(college_name)
    
    # Get the response text and extract acceptance rate
    try:
        # Parse the response text as JSON
        response_text = response.text
        result = json.loads(response_text)
        
        # Extract acceptance rate and convert to decimal
        rate_str = result['acceptance rate'].strip('%')  # Remove % sign
        rate_decimal = float(rate_str) / 100  # Convert to decimal
        
        return rate_decimal
    except (KeyError, ValueError, json.JSONDecodeError):
        # Return None if there's any error in parsing
        return None
    
    # Add a new column 'Acceptance Rate' by applying the function to each college name with rate limiting
def get_acceptance_rates_with_limit(df):
    rates = []
    for i, college in enumerate(df['College Name']):
        # Get acceptance rate for current college
        rate = get_acceptance_rate(college)
        rates.append(rate)

        print (college,  " acceptance rate is ", rate)
        
        # Add delay after every 10 requests
        if (i + 1) % 8 == 0:
            time.sleep(60)  # Wait 60 seconds after every 10 requests
            
    return rates

# %%
# Apply the rate-limited function
df['Acceptance Rate'] = get_acceptance_rates_with_limit(df)
df.to_pickle("Data/ar_df.pkl")

# %% [markdown]
# Program to retrieve lacrosse information and save to pickle

# %%
df = pd.read_pickle("Data/my_df.pkl")

# %%
generation_config_lacrosse = {
  "temperature": 0,
  "top_p": 0.95,
  "top_k": 40,
  "max_output_tokens": 8192,
  "response_schema": content.Schema(
    type = content.Type.OBJECT,
    properties = {
      "has_lacrosse": content.Schema(
        type = content.Type.BOOLEAN,
      ),
      "division": content.Schema(
        type = content.Type.STRING,
      ),
      "conference": content.Schema(
        type = content.Type.STRING,
      ),
    },
  ),
  "response_mime_type": "application/json",
}

lacrosse_model = genai.GenerativeModel(
  model_name="gemini-2.0-flash-exp",
  generation_config=generation_config_lacrosse,
  system_instruction="Seartch the web to determine if the school provided has a women's lacrosse program.  If it does, provide the NCAA divion and conference.",
)

lacrosse_chat_session = lacrosse_model.start_chat()

# %%
def get_lacrosse_info(college_name):
    # Send message to chat session and get response
    response = lacrosse_chat_session.send_message(college_name)
    
    try:
        # Parse the response text as JSON
        response_text = response.text
        result = json.loads(response_text)
        
        # Create a dictionary with the three values
        lacrosse_data = {
            'Has Lacrosse': [result.get('has_lacrosse', False)],
            'Division': [result.get('division', '')],
            'Conference': [result.get('conference', '')]
        }
        
        # Convert to DataFrame
        return pd.DataFrame(lacrosse_data)
        
    except (KeyError, ValueError, json.JSONDecodeError):
        # Return empty DataFrame with the same structure if there's any error
        return pd.DataFrame({
            'Has Lacrosse': [False],
            'Division': [''],
            'Conference': ['']
        })
    
def get_lacrosse_info_with_limit(df):
    all_info = pd.DataFrame()
    request_quota = 10  # requests per minute

    sleep_time = 60 / request_quota
    
    for i, college in enumerate(df['College Name']):
        # Get lacrosse info for current college
        info_df = get_lacrosse_info(college)
        
        # Concatenate with previous results
        all_info = pd.concat([all_info, info_df], ignore_index=True)
        
        print(f"{college} - Has lacrosse: {info_df['Has Lacrosse'].iloc[0]}, Division: {info_df['Division'].iloc[0]}, Conference: {info_df['Conference'].iloc[0]}")
        
        # Add delay after every requests to avoiding hitting the rate limit
        time.sleep(sleep_time)
            
    return all_info

# %%
# Apply the rate-limited function and add the columns to df
lacrosse_info = get_lacrosse_info_with_limit(df)
df[['Has Lacrosse', 'Division', 'Conference']] = lacrosse_info
df.to_pickle("Data/lac_df.pkl")
# Out:
# Princeton University - Has lacrosse: True, Division: NCAA Division I, Conference: Ivy League
# Babson College - Has lacrosse: True, Division: NCAA Division III, Conference: New England Women's and Men's Athletic Conference
# Stanford University - Has lacrosse: True, Division: NCAA Division I, Conference: Pac-12 Conference
# Yale University - Has lacrosse: True, Division: NCAA Division I, Conference: Ivy League
# Claremont McKenna College - Has lacrosse: True, Division: NCAA Division III, Conference: Southern California Intercollegiate Athletic Conference
# Massachusetts Institute of Technology - Has lacrosse: True, Division: NCAA Division III, Conference: New England Women's and Men's Athletic Conference
# Harvard University - Has lacrosse: True, Division: NCAA Division I, Conference: Ivy League
# University of California, Berkeley - Has lacrosse: True, Division: NCAA Division I, Conference: Pac-12 Conference
# Georgia Institute of Technology, Main Campus - Has lacrosse: True, Division: NCAA Division I, Conference: Atlantic Coast Conference
# Davidson College - Has lacrosse: True, Division: NCAA Division I, Conference: Atlant
Has lacrosse: True, Division: NCAA Division I, Conference: Atlantic Sun Conference
# Boston University - Has lacrosse: True, Division: NCAA Division I, Conference: Patriot League
# Wentworth Institute of Technology - Has lacrosse: True, Division: NCAA Division III, Conference: Commonwealth Coast Conference
# Stonehill College - Has lacrosse: True, Division: NCAA Division I, Conference: Northeast Conference
# Williams College - Has lacrosse: True, Division: NCAA Division III, Conference: New England Small College Athletic Conference
# University of New Hampshire, Main Campus - Has lacrosse: True, Division: NCAA Division I, Conference: America East Conference
# McDaniel College - Has lacrosse: True, Division: NCAA Division III, Conference: Centennial Conference
# Wesleyan University - Has lacrosse: True, Division: NCAA Division III, Conference: New England Small College Athletic Conference
# William & Mary - Has lacrosse: True, Division: NCAA Division I, Conference: Colonial Athletic Association
# University of California, Santa Barbara - Has lacrosse: True, Division: NCAA Division I, Conference: Big West Conference
# Kettering University - Has lacrosse: False, Division: , Conference:
# Drexel University - Has lacrosse: True, Division: NCAA Division I, Conference: Colonial Athletic Association
# Missouri University of Science and Technology - Has lacrosse: False, Division: , Conference:
# St. Olaf College - Has lacrosse: True, Division: NCAA Division III, Conference: Minnesota Intercollegiate Athletic Conference
# Spelman College - Has lacrosse: False, Division: , Conference:
# Indiana University, Bloomington - Has lacrosse: True, Division: NCAA Division I, Conference: Big Ten Conference
# Union College - Has lacrosse: True, Division: NCAA Division III, Conference: Liberty League
# SUNY Oneonta - Has lacrosse: True, Division: NCAA Division III, Conference: State University of New York Athletic Conference
# Louisiana State University - Has lacrosse: True, Division: NCAA Division I, Conference: Southeastern Conference
# Susquehanna University - Has lacrosse: True, Division: NCAA Division III, Conference: Landmark Conference
# St. John's University, New York - Has lacrosse: True, Division: NCAA Division I, Conference: Big East Conference
# Pomona College - Has lacrosse: True, Division: NCAA Division III, Conference: Southern California Intercollegiate Athletic Conference
# Dickinson College - Has lacrosse: True, Division: NCAA Division III, Conference: Centennial Conference
# Centre College - Has lacrosse: True, Division: NCAA Division III, Conference: Southern Athletic Association
# Fordham University - Has lacrosse: True, Division: NCAA Division I, Conference: Atlantic 10 Conference
# Creighton University - Has lacrosse: True, Division: NCAA Division I, Conference: Big East Conference
# Temple University - Has lacrosse: True, Division: NCAA Division I, Conference: American Athletic Conference
# St. Lawrence University - Has lacrosse: True, Division: NCAA Division III, Conference: Liberty League
# University at Buffalo, SUNY - Has lacrosse: True, Division: NCAA Division I, Conference: Mid-American Conference
# Florida State University - Has lacrosse: True, Division: NCAA Division I, Conference: Atlantic Coast Conference
# University of Missouri, Columbia - Has lacrosse: True, Division: NCAA Division I, Conference: Southeastern Conference

# %% [markdown]
# US News Rank

# %%
df = pd.read_pickle("Data/lac_df.pkl")

# %%
generation_config_usnews = {
  "temperature": 0,
  "top_p": 0.95,
  "top_k": 40,
  "max_output_tokens": 8192,
  "response_schema": content.Schema(
    type = content.Type.OBJECT,
    properties = {
      "US News Rank": content.Schema(
        type = content.Type.STRING,
      )
    }
  ),
  "response_mime_type": "application/json",
  "candidate_count": 1
}

usnews_model = genai.GenerativeModel(
  model_name="gemini-2.0-flash-exp",
  generation_config=generation_config_usnews,
  system_instruction="Search the web to determine the national ranking of the college according to US News Overall Score rank. Do not consider other rankings like in National Liberal Arts schools",
)

usnews_chat_session = usnews_model.start_chat()

# %%
def get_usnews_info(college_name):
    # Send message to chat session and get response
    response = usnews_chat_session.send_message(college_name)
    
    try:
        # Parse the response text as JSON
        response_text = response.text
        result = json.loads(response_text)
        
        rank_str = result['US News Rank'].strip('%')
        
        return rank_str
        
    except (KeyError, ValueError, json.JSONDecodeError):
        # Return empty DataFrame with the same structure if there's any error
        return None
    
def get_usnews_info_with_limit(df):
    all_info = []
    request_quota = 10  # requests per minute

    sleep_time = 60 / request_quota
    
    for i, college in enumerate(df['College Name']):
        info = get_usnews_info(college)
        all_info.append(info)
        
        print(f"{college} rank is {info}")
        
        # Add delay after every requests to avoiding hitting the rate limit
        time.sleep(sleep_time)
    
    return all_info

# %%
df['US News Rank'] = get_usnews_info_with_limit(df)
df.to_pickle("Data/un_df.pkl")
# Out:
# Princeton University rank is 1
# Babson College rank is 34
# Stanford University rank is 3
# Yale University rank is 5
# Claremont McKenna College rank is 8
# Massachusetts Institute of Technology rank is 2
# Harvard University rank is 3
# University of California, Berkeley rank is 15
# Georgia Institute of Technology, Main Campus rank is 33
# Davidson College rank is 17
# Bentley University rank is 68
# University of California, Davis rank is 28
# University of Pennsylvania rank is 7
# Columbia University rank is 12
# Lehigh University rank is 51
# San José State University rank is 187
# University of Notre Dame rank is 20
# University of California, Merced rank is 97
# Virginia Tech rank is 47
# Harvey Mudd College rank is 36
# California State Polytechnic University, Pomona rank is 151
# University of Michigan, Ann Arbor rank is 21
# Loyola University Maryland rank is 115
# California State University, Stanislaus rank is 187
# Colgate University rank is 25
# University of Delaware rank is 76
# Cornell University rank is 12
# Texas A & M University, College Station rank is 47
# Rice University rank is 17
# University of California, San Diego rank is 34
# University of California, Irvine rank is 33
# Washington University in St. Louis rank is 24
# University of Virginia, Main Campus rank is 24
# Georgetown University rank is 22
# Swarthmore College rank is 4
# Brown University rank is 9
# Augustana College rank is 105
# Santa Clara University rank is 60
# California Institute of Technology rank is 1
# Towson University rank is 115
# University of Texas at Austin rank is 32
# St. Joseph's University rank is 137
# University of Detroit Mercy rank is 187
# Vanderbilt University rank is 18
# Duke University rank is 7
# California State University, San Bernardino rank is 187
# University of San Diego rank is 97
# California Polytechnic State University, San Luis Obispo rank is 60
# University of Southern California rank is 28
# Washington and Lee University rank is 17
# California State University, Fresno rank is 187
# Manhattan University* rank is 137
# University of Illinois Urbana-Champaign rank is 35
# Albion College rank is 127
# Marquette University rank is 86
# Carnegie Mellon University rank is 22
# Dartmouth College rank is 18
# Lafayette College rank is 36
# University of North Carolina at Chapel Hill rank is 28
# Michigan State University rank is 60
# Baruch College, CUNY rank is 187
# Northwestern University rank is 9
# Brigham Young University rank is 89
# Colby College rank is 17
# College of the Holy Cross rank is 36
# San Francisco State University rank is 187
# California State University, Long Beach rank is 187
# University of California, Los Angeles rank is 15
# Siena College rank is 137
# James Madison University rank is 115
# University of Portland rank is 137
# California State University, Sacramento rank is 187
# University of Wisconsin, Madison rank is 35
# Bryant University rank is 115
# University of Chicago rank is 12
# George Mason University rank is 115
# Florida International University rank is 151
# University of Dayton rank is 137
# Villanova University rank is 67
# University of La Verne rank is 187
# California State University, Northridge rank is 187
# University of Washington rank is 40
# University of Florida rank is 28
# University of Rhode Island rank is 151
# California State University, Fullerton rank is 187
# Wellesley College rank is 5
# University of the Pacific rank is 137
# Haverford College rank is 17
# Ohio Northern University rank is 151
# Worcester Polytechnic Institute rank is 67
# Quinnipiac University rank is 187
# Johns Hopkins University rank is 9
# Clemson University rank is 67
# The College of New Jersey rank is 76
# California State University, Los Angeles rank is 187
# Bucknell University rank is 36
# California State University, San Marcos rank is 187
# Rose-Hulman Institute of Technology rank is 1
# University of Connecticut rank is 67
# Boston College rank is 39
# Azusa Pacific University rank is 187
# Purdue University, Main Campus rank is 43
# Emory University rank is 24
# Colorado School of Mines rank is 67
# Providence College rank is 137
# Montclair State University rank is 187
# University of Redlands rank is 137
# University of California, Riverside rank is 89
# University of Illinois, Chicago rank is 82
# Franklin and Marshall College rank is 36
# Muhlenberg College rank is 76
# Adelphi University rank is 187
# University of Maryland, College Park rank is 58
# New Jersey Institute of Technology rank is 89
# Hampden-Sydney College rank is 127
# Fairfield University rank is 115
# DePauw University rank is 46
# Bradley University rank is 137
# Iowa State University rank is 115
# Amherst College rank is 2
# University of Richmond rank is 28
# DePaul University rank is 137
# Washington & Jefferson College rank is 127
# Rutgers University rank is 55
# University of Scranton rank is 115
# Gonzaga University rank is 89
# Stevens Institute of Technology rank is 67
# Thomas Jefferson University rank is 137
# George Washington University rank is 67
# University of San Francisco rank is 115
# Wofford College rank is 76
# Illinois Wesleyan University rank is 76
# Marist College rank is 137
# University of St. Francis rank is 187
# Kalamazoo College rank is 105
# Butler University rank is 115
# Wake Forest University rank is 28
# Clarkson University rank is 137
# Indiana Wesleyan University, Marion rank is 187
# Iona University rank is 137
# Fresno Pacific University rank is 187
# University of Oklahoma, Norman Campus rank is 137
# Rensselaer Polytechnic Institute rank is 51
# Duquesne University rank is 151
# Pepperdine University rank is 67
# Michigan Technological University rank is 137
# Illinois State University rank is 187
# Barnard College rank is 17
# University of Utah rank is 105
# Washington State University rank is 187
# University of Georgia rank is 47
# Binghamton University, SUNY rank is 89
# Illinois Institute of Technology rank is 105
# Drake University rank is 137
# Elon University rank is 89
# Hamline University rank is 137
# St. Louis University rank is 105
# California State University, Monterey Bay rank is 187
# University at Albany, SUNY rank is 187
# Salve Regina University rank is 137
# Bowdoin College rank is 6
# University of Iowa rank is 82
# San Diego State University rank is 105
# Syracuse University rank is 67
# Milwaukee School of Engineering rank is 137
# Gettysburg College rank is 51
# North Carolina State University, Raleigh rank is 43
# Northeastern University, Boston rank is 53
# Auburn University rank is 97
# University of North Florida rank is 187
# Boston University rank is 43
# Wentworth Institute of Technology rank is 187
# Stonehill College rank is 115
# Williams College rank is 1
# University of New Hampshire, Main Campus rank is 137
# McDaniel College rank is 137
# Wesleyan University rank is 17
# William & Mary rank is 47
# University of California, Santa Barbara rank is 35
# Kettering University rank is 137
# Drexel University rank is 97
# Missouri University of Science and Technology rank is 105
# St. Olaf College rank is 67
# Spelman College rank is 51
# Indiana University, Bloomington rank is 73
# Union College rank is 46
# SUNY Oneonta rank is 187
# Louisiana State University rank is 151
# Susquehanna University rank is 127
# St. John's University, New York rank is 187
# Pomona College rank is 4
# Dickinson College rank is 51
# Centre College rank is 67
# Fordham University rank is 89
# Creighton University rank is 137
# Temple University rank is 89
# St. Lawrence University rank is 67
# University at Buffalo, SUNY rank is 89
# Florida State University rank is 53
# University of Missouri, Columbia rank is 127

# %% [markdown]
# Data Exploration

# %%
# Filter df to only include schools with lacrosse programs
lacrosse_schools = df[df['Has Lacrosse'] == True]
print(f"Number of schools with lacrosse programs: {len(lacrosse_schools)}")
display(lacrosse_schools)
# Out:
# Number of schools with lacrosse programs: 167
#                          College Name  Acceptance Rate  WSJ Rank  \
# 0                Princeton University            0.057         1
# 1                      Babson College            0.250         2
# 2                 Stanford University            0.039         3
# 3                     Yale University            0.045         4
# 4           Claremont McKenna College            0.100         5
# ..                                ...              ...       ...
# 195                 Temple University            0.710       196
# 196           St. Lawrence University            0.500       197
# 197       University at Buffalo, SUNY            0.710       198
# 198          Florida State University            0.250       199
# 199  University of Missouri, Columbia            0.790       200
#
#      Has Lacrosse           Division  \
# 0            True    NCAA Division I
# 1            True  NCAA Division III
# 2            True    NCAA Division I
# 3            True    NCAA Division I
# 4            True  NCAA Division III
# ..            ...                ...
# 195          True    NCAA Division I
# 196          True  NCAA Division III
# 197          True    NCAA Division I
# 198          True    NCAA Division I
# 199          True    NCAA Division I
#
#                                             Conference US News Rank
# 0                                           Ivy League            1
# 1    New England Women's and Men's Athletic Conference           34
# 2                                    Pac-12 Conference            3
# 3                                           Ivy League            5
# 4    Southern California Intercollegiate Athletic C...            8
# ..                                                 ...          ...
# 195                       American Athletic Conference           89
# 196                                     Liberty League           67
# 197                            Mid-American Conference           89
# 198                          Atlantic Coast Conference           53
# 199                            Southeastern Conference          127
#
# [167 rows x 7 columns]

# %%
filtered_schools = lacrosse_schools[lacrosse_schools['Acceptance Rate'] >= 0.07]
print(f"Number of schools with lacrosse programs and acceptance rate >= 7%: {len(filtered_schools)}")
display(filtered_schools)
# Out:
# Number of schools with lacrosse programs and acceptance rate >= 5%: 154
#                                      College Name  Acceptance Rate  WSJ Rank  \
# 1                                  Babson College            0.250         2
# 4                       Claremont McKenna College            0.100         5
# 7              University of California, Berkeley            0.113         8
# 8    Georgia Institute of Technology, Main Campus            0.160         9
# 9                                Davidson College            0.130        10
# ..                                            ...              ...       ...
# 195                             Temple University            0.710       196
# 196                       St. Lawrence University            0.500       197
# 197                   University at Buffalo, SUNY            0.710       198
# 198                      Florida State University            0.250       199
# 199              University of Missouri, Columbia            0.790       200
#
#      Has Lacrosse           Division  \
# 1            True  NCAA Division III
# 4            True  NCAA Division III
# 7            True    NCAA Division I
# 8            True    NCAA Division I
# 9            True    NCAA Division I
# ..            ...                ...
# 195          True    NCAA Division I
# 196          True  NCAA Division III
# 197          True    NCAA Division I
# 198          True    NCAA Division I
# 199          True    NCAA Division I
#
#                                             Conference US News Rank
# 1    New England Women's and Men's Athletic Conference           34
# 4    Southern California Intercollegiate Athletic C...            8
# 7                                    Pac-12 Conference           15
# 8                            Atlantic Coast Conference           33
# 9                               Atlantic 10 Conference           17
# ..                                                 ...          ...
# 195                       American Athletic Conference           89
# 196                                     Liberty League           67
# 197                            Mid-American Conference           89
